# %% [markdown]
# # CS 1656 – Introduction to Data Science
#
# ## Instructor: Alexandros Labrinidis
# ## Teaching Assistant: Evangelos Karageorgos
# ### Additional credits: Xiaoting Li, Tahereh Arabghalizi, Zuha Agha, Anatoli Shein, Phuong Pham
# ## Recitation : SQL via Data API
# ---
# In this recitation, you will execute SQL queries on real data by connecting to the open data portal of [Western Pennsylavnia Regional Data Center](https://www.wprdc.org/) and requesting data via API calls.

# %%
import json
from datetime import datetime, timedelta, date
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# We will be using Allegheny County Restaurant/Food Facility Inspection Violation Dataset found here https://data.wprdc.org/dataset/allegheny-county-restaurant-food-facility-inspection-violations. This dataset contains violation data from actual routine inspections by one of health department staff's members for the last two years. It should be fun to find out inspection results for places where we eat in Pittsburgh! =)

# %%
wprdc_api_endpoint = "https://data.wprdc.org/api/3/action/datastore_search_sql"

# id for database table
resource_id = "1a1329e2-418c-4bd3-af2c-cc334e7559af"

# Get the date from 270 days ago)
# end_date = datetime.now()
# start_date = end_date - timedelta(days=270)

# Get two date endpoints
start_date = date(2021, 9, 1)
end_date = date(2022, 6, 1)

# Convert to a string the format the the data center accepts (yyyy-mm-dd)
start_str = start_date.strftime("%Y-%m-%d")
end_str = end_date.strftime("%Y-%m-%d")

# SQL query we'll use in API call to request data
query = """
SELECT *
FROM "{}"
WHERE "inspect_dt" BETWEEN '{}' and '{}' AND "city" = '{}'""".format(resource_id, start_str, end_str, "Pittsburgh")

# Make WPRDC API Call
response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)

# Parse response JSON into python dictionary
response_data = json.loads(response.text)

# Convert dictionary to dataframe
df = pd.DataFrame.from_dict(response_data['result']['records'])

# Print the number of rows
print(df.shape[0], "rows total")
print(df.columns)
df[1:30]
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 10423 rows total
# Index(['inspect_dt', 'rating', 'bus_st_date', 'high', 'street', 'id',
#        'municipal', 'city', 'zip', 'state', 'low', 'facility_name', 'medium',
#        'description', 'start_time', 'placard_st', 'description_new',
#        'encounter', 'url', '_full_text', 'num', 'end_time', '_id'],
#       dtype='object')
#     inspect_dt rating bus_st_date  high           street            id  \
# 1   2021-12-07      V  2001-08-14  None  Unity Center Rd  200109170005
# 2   2021-12-09      V  2022-01-04  None   Butler  Street  202112090003
# 3   2021-12-09      V  2022-01-04  None   Butler  Street  202112090003
# 4   2021-09-02      V  2021-09-02     F     Beverly Road  202109020006
# 5   2021-09-01      V  2007-11-15     F   Carson  Street  200711150004
# 6   2021-09-01      V  2007-11-15     F   Carson  Street  200711150004
# 7   2021-09-01      V  2007-11-15     F   Carson  Street  200711150004
# 8   2021-09-01      V  2007-11-15  None   Carson  Street  200711150004
# 9   2021-09-01      V  1984-06-17  None   Forbes  Avenue         18094
# 10  2021-09-01      V  2021-09-02     F  Braddock Avenue  202109010003
# 11  2021-09-01      V  2021-09-02     F  Braddock Avenue  202109010003
# 12  2021-09-01      V  2021-09-02     F  Braddock Avenue  202109010003
# 13  2021-09-01      V  2021-09-02  None  Braddock Avenue  202109010003
# 14  2021-09-01      V  2021-09-02  None  Braddock Avenue  202109010003
# 15  2021-09-01      V  2021-09-02  None  Braddock Avenue  202109010003
# 16  2021-09-01      V  2010-08-20     F   Liberty Avenue  201008260003
# 17  2021-09-01      V  2010-08-20     F   Liberty Avenue  201008260003
# 18  2021-09-01      V  2004-05-21     T  Smallman Street  200405210005
# 19  2021-09-01      V  2004-05-21     F  Smallman Street  200405210005
# 20  2021-09-01      V  2004-05-21     F  Smallman Street  200405210005
# 21  2021-09-01      V  2004-05-21     T  Smallman Street  200405210005
# 22  2021-09-01      V  2004-05-21     T  Smallman Street  200405210005
# 23  2021-09-01      V  2004-05-21     F  Smallman Street  200405210005
# 24  2021-09-01      V  2004-05-21     T  Smallman Street  200405210005
# 25  2021-09-01      V  2004-05-21     F  Smallman Street  200405210005
# 26  2021-09-01      V  2004-05-21     F  Smallman Street  200405210005
# 27  2021-09-01      V  2004-05-21  None  Smallman Street  200405210005
# 28  2021-09-01      V  2004-05-21  None  Smallman Street  200405210005
# 29  2021-09-01      V  2004-05-21  None  Smallman Street  200405210005
#
#          municipal        city    zip state  ...  \
# 1             Plum  Pittsburgh  15239    PA  ...
# 2             Etna  Pittsburgh  15223    PA  ...
# 3             Etna  Pittsburgh  15223    PA  ...
# 4       Mt Lebanon  Pittsburgh  15216    PA  ...
# 5   Pittsburgh-116  Pittsburgh  15203    PA  ...
# 6   Pittsburgh-116  Pittsburgh  15203    PA  ...
# 7   Pittsburgh-116  Pittsburgh  15203    PA  ...
# 8   Pittsburgh-116  Pittsburgh  15203    PA  ...
# 9   Pittsburgh-114  Pittsburgh  15217    PA  ...
# 10        Edgewood  Pittsburgh  15218    PA  ...
# 11        Edgewood  Pittsburgh  15218    PA  ...
# 12        Edgewood  Pittsburgh  15218    PA  ...
# 13        Edgewood  Pittsburgh  15218    PA  ...
# 14        Edgewood  Pittsburgh  15218    PA  ...
# 15        Edgewood  Pittsburgh  15218    PA  ...
# 16  Pittsburgh-106  Pittsburgh  15201    PA  ...
# 17  Pittsburgh-106  Pittsburgh  15201    PA  ...
# 18  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 19  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 20  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 21  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 22  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 23  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 24  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 25  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 26  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 27  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 28  Pittsburgh-102  Pittsburgh  15222    PA  ...
# 29  Pittsburgh-102  Pittsburgh  15222    PA  ...
#
#                            description start_time placard_st  \
# 1                       Food Processor   09:45:00          1
# 2                               Bakery   14:00:00          4
# 3                               Bakery   14:00:00          4
# 4                               Bakery   11:50:00          1
# 5               Restaurant with Liquor   13:15:00          1
# 6               Restaurant with Liquor   13:15:00          1
# 7               Restaurant with Liquor   13:15:00          1
# 8               Restaurant with Liquor   13:15:00          1
# 9                       Church Kitchen   13:10:00          1
# 10  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 11  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 12  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 13  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 14  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 15  Mobile - Tier II ( Prepared Foods)   15:15:00          1
# 16           Traditional Boarding Home   11:15:00          1
# 17           Traditional Boarding Home   11:15:00          1
# 18              Restaurant with Liquor   16:05:00          1
# 25  http://appsrv.alleghenycounty.us/reports/rwser...
# 26  http://appsrv.alleghenycounty.us/reports/rwser...
# 27  http://appsrv.alleghenycounty.us/reports/rwser...
# 28  http://appsrv.alleghenycounty.us/reports/rwser...
# 29  http://appsrv.alleghenycounty.us/reports/rwser...
#
#                                            _full_text   num  end_time     _id
# 1   '-07':23 '-08':9 '-12':22 '-14':10 '/reports/r...  1055  11:00:00  294453
# 2   '-01':7 '-04':8 '-09':19 '-12':18 '/reports/rw...   372  16:20:00  294623
# 3   '-01':7 '-04':8 '-09':21 '-12':20 '/reports/rw...   372  16:20:00  294624
# 4   '-02':8,19 '-09':7,18 '/reports/rwservlet?food...  300C  13:40:00  255186
# 5   '-01':25 '-09':24 '-11':8 '-116':33 '-15':9 '/...  2122  14:35:00  255084
# 6   '-01':23 '-09':22 '-11':8 '-116':31 '-15':9 '/...  2122  14:35:00  255085
# 7   '-01':26 '-09':25 '-11':8 '-116':34 '-15':9 '/...  2122  14:35:00  255086
# 8   '-01':22 '-09':21 '-11':8 '-116':30 '-15':9 '/...  2122  14:35:00  255087
# 9   '-01':22 '-06':7 '-09':21 '-114':30 '-17':8 '/...  5505  13:20:00  255088
# 10  '-01':28 '-02':12 '-09':11,27 '-2814':8 '/repo...  1621  16:20:00  255101
# 11  '-01':28 '-02':12 '-09':11,27 '-2814':8 '/repo...  1621  16:20:00  255102
# 12  '-01':31 '-02':12 '-09':11,30 '-2814':8 '/repo...  1621  16:20:00  255103
# 13  '-01':27 '-02':12 '-09':11,26 '-2814':8 '/repo...  1621  16:20:00  255104
# 14  '-01':29 '-02':12 '-09':11,28 '-2814':8 '/repo...  1621  16:20:00  255105
# 15  '-01':28 '-02':12 '-09':11,27 '-2814':8 '/repo...  1621  16:20:00  255106
# 16  '-01':23 '-08':7 '-09':22 '-106':31 '-20':8 '/...  3501  12:15:00  255107
# 17  '-01':22 '-08':7 '-09':21 '-106':30 '-20':8 '/...  3501  12:15:00  255108
# 18  '-01':22 '-05':6 '-09':21 '-102':30 '-21':7 '/...  1150  18:50:00  255109
# 19  '-01':23 '-05':6 '-09':22 '-102':31 '-21':7 '/...  1150  18:50:00  255110
# 20  '-01':23 '-05':6 '-09':22 '-102':31 '-21':7 '/...  1150  18:50:00  255111
# 21  '-01':23 '-05':6 '-09':22 '-102':31 '-21':7 '/...  1150  18:50:00  255134
# 22  '-01':22 '-05':6 '-09':21 '-102':30 '-21':7 '/...  1150  18:50:00  255135
# 23  '-01':22 '-05':6 '-09':21 '-102':30 '-21':7 '/...  1150  18:50:00  255136
# 24  '-01':21 '-05':6 '-09':20 '-102':29 '-21':7 '/...  1150  18:50:00  255137
# 25  '-01':25 '-05':6 '-09':24 '-102':33 '-21':7 '/...  1150  18:50:00  255138
# 26  '-01':24 '-05':6 '-09':23 '-102':32 '-21':7 '/...  1150  18:50:00  255139
# 27  '-01':22 '-05':6 '-09':21 '-102':30 '-21':7 '/...  1150  18:50:00  255140
# 28  '-01':22 '-05':6 '-09':21 '-102':30 '-21':7 '/...  1150  18:50:00  255141
# 29  '-01':20 '-05':6 '-09':19 '-102':28 '-21':7 '/...  1150  18:50:00  255142
#
# [29 rows x 23 columns]

# %% [markdown]
# Details of dataset attributes are below. ((Taken from https://data.wprdc.org/dataset/allegheny-county-restaurant-food-facility-inspection-violations/resource/1a1329e2-418c-4bd3-af2c-cc334e7559af)
# ![title](attribs.png)

# %% [markdown]
# ## Queries
#
# __Q1) Find all unique decription categories of violation in Pittsburgh restaurants over the time span (violation description[violation]).__

# %%
query = """
SELECT DISTINCT "description_new" as violation
FROM "{}"
WHERE "inspect_dt" BETWEEN '{}' and '{}' AND "city" = '{}' """.format(resource_id, start_str, end_str, "Pittsburgh")

response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)

df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])

df
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                             violation
# 0                                    General Premises
# 1                                            Lighting
# 2                           Cold Holding Temperatures
# 3                                         Toilet Room
# 4                                   Consumer Advisory
# 5                                  Garbage and Refuse
# 6                                         Toxic Items
# 7                           Cleaning and Sanitization
# 8                          Demonstration of Knowledge
# 9                              Reheating Temperatures
# 10                 Facilities to Maintain Temperature
# 11                  Certified Food Protection Manager
# 12                                           Plumbing
# 13                           Hot Holding Temperatures
# 14                             Handwashing Facilities
# 15  Fabrication, Design, Installation and Maintenance
# 16                               Date Marking of Food
# 17                                        Ventilation
# 18                               Waste Water Disposal
# 19                              Food Source/Condition
# 20                                     Administrative
# 21  Contamination Prevention - Food, Utensils and ...
# 22                            Probe-Type Thermometers
# 23                          Employee Personal Hygiene
# 24                                 Walls and ceilings
# 25                                       Cooling Food
# 26                               Cooking Temperatures
# 27                     Cross-Contamination Prevention
# 28                                             Floors
# 29                                       Water Supply
# 30                                    Pest Management
# 31                    Dressing rooms and Locker rooms

# %% [markdown]
# __Q2) Find restaurants in Pittsburgh with no violations in at least one decription category (facility name[facility], number of violations[count]).__

# %%
query = """
SELECT "facility_name" as facility, COUNT("description_new") as count
FROM "{}"
WHERE "inspect_dt" BETWEEN '{}' and '{}' AND "city" = '{}' AND "rating" = '{}'
GROUP BY "facility_name" """.format(resource_id, start_str, end_str, "Pittsburgh", "V")

response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)

df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])

df
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#      count                                    facility
# 0        5                         Mindy's Take & Bake
# 1       10                      The Cheesecake Factory
# 2        1                                 Burden Test
# 3        1  American Legion George Walter Jr Post #106
# 4        7                     Gordo's Tacos & Tequila
# ...    ...                                         ...
# 1894     1             Catalyst Academy Charter School
# 1895     5                              La Gourmandine
# 1896     1      Washington Elementary School Cafeteria
# 1897     1                   Crafton Ice Cream Delight
# 1898     6               Big Shot Bob's House of Wings
#
# [1899 rows x 2 columns]

# %% [markdown]
# ### Tasks
#
# __Tasks 1 to 4 must be implemented in Task.py__
#
# __T1) Find top 30 restaurants in Pittsburgh with maximum number of violations (facility name[facility], number of violations[count]).__

# %%
query = """
            SELECT "facility_name" as facility ,  COUNT("description_new") as count
            FROM "{}"
            WHERE "inspect_dt" BETWEEN '{}' and '{}' AND "city" = '{}'
            GROUP BY facility
            ORDER BY "count" DESC
            LIMIT 30 
            """.format(resource_id, start_str, end_str, "Pittsburgh")
response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)
df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])
df
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#    count                           facility
# 0     58   A's 2's / Ace's & Deuce's Lounge
# 1     48       Caliente Pizza & Draft House
# 2     47         Subway Sandwiches & Salads
# 3     44           Shrodi's Cucina di Maria
# 4     40                     Uptown Kitchen
# 5     36    Jimmy Wan's Restaurant & Lounge
# 6     36                      Silk Elephant
# 7     35                    Ocean Treasures
# 8     34      California Taco Shop - Shaler
# 9     32          Piada Italian Street Food
# 10    32              Italian Village Pizza
# 11    31                     Farmer x Baker
# 12    31  Subway Sandwiches & Salads #28039
# 13    30            Papa Allen's / Papa Bar
# 14    30                    Chengdu Gourmet
# 15    29                 Bombay Food Market
# 16    29            Hokkaido Seafood Buffet
# 17    29               Victory Banquet Hall
# 18    28                         McDonald's
# 19    28                   Dagu Rice Noodle
# 20    28              Allegheny County Jail
# 21    27                 The Yard Gastropub
# 22    27        Atria's Restaurant & Tavern
# 23    27             Miller's Seafood House
# 24    26               Hook, Fish & Chicken
# 25    26                   Carmody's Grille
# 26    26                 Samovar Restaurant
# 27    25        Shah's Halal Food @ Walmart
# 28    25                         Happy Mart
# 29    24                      Vocelli Pizza

# %% [markdown]
# Lets look more closely into the inspection results of Pitt facilities.
#
# __T2) Find the category descriptions and their high, medium, low risk ratings for all violations at facilities that start with 'Pitt' over the past nine months (facility name[facility], violation description[violation], rating[rating], high[high], medium[medium], low[low]).__

# %%
query = """
            SELECT "facility_name" as facility, "description_new" as violation,
               "rating", "high", "medium", "low"
            FROM "{}"
            WHERE "inspect_dt" BETWEEN '{}' AND '{}' AND "city" = '{}'
            AND "rating" = '{}' AND "facility_name" LIKE 'Pitt%' AND ("high" = 'T' OR "medium" = 'T' OR "low" = 'T')
            
            """.format(resource_id, start_str, end_str, "Pittsburgh", "V")
response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)
df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])
df
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#    rating medium                                           facility  \
# 0       V      F  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 1       V      F  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 2       V      F  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 3       V   None  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 4       V   None  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 5       V   None  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 6       V      F  Pitt Eats William Pitt Union / Schenley Cafe &...
# 7       V      F              Pitt Eats William Pitt Union / Nordys
# 8       V      F              Pitt Eats William Pitt Union / Nordys
# 9       V      F          Pitt Eats Victoria Hall / Victoria Coffee
# 10      V      F                  Pittsburgh Chinese Church Oakland
# 11      V      F  Pitt Eats Litchfield Tower (B) / The Eatery at...
# 12      V      T        Pittsburgh Sandwich Society @ Strange Roots
# 13      V      F        Pittsburgh Sandwich Society @ Strange Roots
# 14      V      F        Pittsburgh Sandwich Society @ Strange Roots
# 15      V   None  Pitt Eats Litchfield Tower (B) / Litchfield Co...
# 16      V      F         Pitt Hillman Library Ground Level / Saxbys
# 17      V      F         Pitt Hillman Library Ground Level / Saxbys
# 18      V      F                  Pitt Eats Alumni Hall / Cafe 1787
# 19      V      F                Pitt Cathedral of Learning / Saxbys
# 20      V      F                Pitt Cathedral of Learning / Saxbys
# 21      V      F         Pitt Eats Mervis Hall / Bottom Line Bistro
# 22      V   None         Pitt Eats Mervis Hall / Bottom Line Bistro
# 23      V      F        Pitt Eats Barco Law Building / Sidebar Cafe
# 24      V      F                     Pittsburgh Playhouse Lobby Bar
# 25      V      F       Pitt Eats Langley Hall / Langley Hall Coffee
# 26      V      F              Pitt Eats Commissary / Posvar Kitchen
# 27      V      F              Pitt Eats Commissary / Posvar Kitchen
# 28      V   None              Pitt Eats Commissary / Posvar Kitchen
# 29      V   None              Pitt Eats Commissary / Posvar Kitchen
# 30      V      F      Pitt Eats Benedum Hall / Einstein Bros Bagels
# 31      V      F                              Pittsburgh Popcorn Co
# 32      V      F              Pitt Eats Sutherland Hall / The Perch
# 33      V      F              Pitt Eats Sutherland Hall / The Perch
# 34      V      F              Pitt Eats Sutherland Hall / The Perch
# 35      V      T  Pitt Eats William Pitt Union / Schenley Cafe &...
# 36      V      F                              Pittsburgh Popcorn Co
# 37      V      F                              Pittsburgh Popcorn Co
# 38      V      T                                   Pitt's Dogg'n It
# 39      V      F  Pitt Eats Cathedral of Learning / Cathedral Ca...
# 40      V      T  Pitt Eats Cathedral of Learning / Cathedral Ca...
# 41      V      F  Pitt Eats Cathedral of Learning / Cathedral Ca...
# 42      V   None  Pitt Eats Cathedral of Learning / Cathedral Ca...
# 43      V      F  Pitt Eats William Pitt Union / Schenley Cafe &...
# 44      V   None  Pitt Eats William Pitt Union / Schenley Cafe &...
# 45      V   None  Pitt Eats William Pitt Union / Schenley Cafe &...
# 46      V      F                 Pitt Eats Posvar Hall / Einstein's
# 47      V      F       Pitt Eats Parran Hall / Public Health Coffee
# 48      V      T       Pitt Eats Parran Hall / Public Health Coffee
# 49      V      F       Pitt Eats Parran Hall / Public Health Coffee
# 50      V      F    Pitt Eats Sutherland Hall / Market @ Sutherland
# 51      V      F    Pitt Eats Sutherland Hall / Market @ Sutherland
# 52      V      F                                 Pittsburgh Popcorn
# 53      V   None                                 Pittsburgh Popcorn
# 54      V      F  Pitt Eats William Pitt Union / Schenley Cafe &...
#
#                                             violation  high low
# 0                  Facilities to Maintain Temperature     F   T
# 1   Contamination Prevention - Food, Utensils and ...     F   T
# 2   Fabrication, Design, Installation and Maintenance     F   T
# 3                                              Floors  None   T
# 4                                            Lighting  None   T
# 5                                    General Premises  None   T
# 6   Fabrication, Design, Installation and Maintenance     F   T
# 7                              Handwashing Facilities     F   T
# 8   Fabrication, Design, Installation and Maintenance     F   T
# 9   Fabrication, Design, Installation and Maintenance     F   T
# 10                          Cleaning and Sanitization     F   T
# 11                                    Pest Management     F   T
# 12                     Cross-Contamination Prevention     F   F
# 13                               Waste Water Disposal     F   T
# 14                             Handwashing Facilities     F   T
# 15                                 Walls and ceilings  None   T
# 16                             Handwashing Facilities     F   T
# 17  Fabrication, Design, Installation and Maintenance     F   T
# 18  Fabrication, Design, Installation and Maintenance     F   T
# 19                          Cleaning and Sanitization     F   T
# 20  Fabrication, Design, Installation and Maintenance     F   T
# 21  Fabrication, Design, Installation and Maintenance     F   T
# 22                                 Walls and ceilings  None   T
# 23  Fabrication, Design, Installation and Maintenance     F   T
# 24                          Cleaning and Sanitization     F   T
# 25                             Handwashing Facilities     F   T
# 26  Contamination Prevention - Food, Utensils and ...     F   T
# 27  Fabrication, Design, Installation and Maintenance     F   T
# 28                                 Walls and ceilings  None   T
# 29                                   General Premises  None   T
# 30  Fabrication, Design, Installation and Maintenance     F   T
# 31  Fabrication, Design, Installation and Maintenance     F   T
# 32                             Handwashing Facilities     F   T
# 33  Contamination Prevention - Food, Utensils and ...     F   T
# 34                                        Toilet Room     F   T
# 35                           Hot Holding Temperatures     F   F
# 36                          Cleaning and Sanitization     F   T
# 37  Fabrication, Design, Installation and Maintenance     F   T
# 38                             Handwashing Facilities     F   F
# 39                          Cold Holding Temperatures     T   F
# 40                 Facilities to Maintain Temperature     F   F
# 41  Fabrication, Design, Installation and Maintenance     F   T
# 42                                 Walls and ceilings  None   T
# 43  Fabrication, Design, Installation and Maintenance     F   T
# 44                                 Walls and ceilings  None   T
# 45                                           Lighting  None   T
# 46  Fabrication, Design, Installation and Maintenance     F   T
# 47                          Cold Holding Temperatures     T   F
# 48                 Facilities to Maintain Temperature     F   F
# 49  Fabrication, Design, Installation and Maintenance     F   T
# 50                                           Plumbing     F   T
# 51  Fabrication, Design, Installation and Maintenance     F   T
# 52                          Cleaning and Sanitization     F   T
# 53                                           Lighting  None   T
# 54                          Cleaning and Sanitization     F   T

# %% [markdown]
# Now lets look at all facilities that contain word 'Pitt'.
#
# __T3) Find the category descriptions and their high, medium, low risk ratings for all violations at all facilities that have word 'Pitt' in their name. Note that results that contain word 'Pitt' as part of another word (e.g. 'Pittsburgh') should not be included (facility name[facility], violation description[violation], rating[rating], high[high], medium[medium], low[low])__

# %%
query = """
            SELECT "facility_name" as facility ,  "description_new" as violation, "high" as h, "medium" as m, "low" as l, "rating" as r
            FROM "{}"
            WHERE "inspect_dt" BETWEEN '{}' and '{}' AND "city" = '{}' AND ("facility_name" LIKE '% Pitt %' OR "facility_name" LIKE 'Pitt %' OR "facility_name" LIKE '% Pitt')
            
            """.format(resource_id, start_str, end_str, "Pittsburgh")
response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)
df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])
df
# Out:
# C:\Users\arhat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.wprdc.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#
Fabrication, Design, Installation and Maintenance     F     F     T  V
# 12                                        Toilet Room     F     F     F  V
# 13                                             Floors  None  None     T  V
# 14                                 Walls and ceilings  None  None     T  V
# 15  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 16                                    Pest Management     F     F     T  V
# 17                                 Walls and ceilings  None  None     T  V
# 18                             Handwashing Facilities     F     F     T  V
# 19  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 20  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 21                          Cleaning and Sanitization     F     F     T  V
# 22  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 23  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 24                                 Walls and ceilings  None  None     T  V
# 25  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 26                             Handwashing Facilities     F     F     T  V
# 27  Contamination Prevention - Food, Utensils and ...     F     F     T  V
# 28  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 29                                 Walls and ceilings  None  None     T  V
# 30                                   General Premises  None  None     T  V
# 31  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 32                             Handwashing Facilities     F     F     T  V
# 33  Contamination Prevention - Food, Utensils and ...     F     F     T  V
# 34                                        Toilet Room     F     F     T  V
# 35                           Hot Holding Temperatures     F     T     F  V
# 36                          Cleaning and Sanitization     F     F     T  V
# 37                                   General Premises  None  None     T  V
# 38                                     Administrative  None  None  None  V
# 39                          Cold Holding Temperatures     T     F     F  V
# 40                 Facilities to Maintain Temperature     F     T     F  V
# 41  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 42                                 Walls and ceilings  None  None     T  V
# 43                 Facilities to Maintain Temperature     F     F     F  V
# 44  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 45                                 Walls and ceilings  None  None     T  V
# 46                                           Lighting  None  None     T  V
# 47  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 48                          Cold Holding Temperatures     T     F     F  V
# 49                 Facilities to Maintain Temperature     F     T     F  V
# 50  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 51                               Waste Water Disposal     F     F     T  N
# 52                          Cleaning and Sanitization     F     F     T  V
# 53                                           Plumbing     F     F     T  V
# 54  Fabrication, Design, Installation and Maintenance     F     F     T  V
# 55                          Cleaning and Sanitization     F     F     T  V

# %% [markdown]
# __T4) Find top 20 facilities that have word 'Pitt' in their name and have the highest counts of violations (facility name[facility], number of violations[count]).__

# %%
query = """
            SELECT "facility_name" as facility , COUNT("description_new") as count
            FROM "{}"
            WHERE "inspect_dt" BETWEEN '{}' AND '{}' AND "city" = '{}' AND "rating" = '{}' AND "facility_name" LIKE '%Pitt%'
            GROUP BY "facility_name"
            ORDER BY "count" DESC
            LIMIT 20 
            """.format(resource_id, start_str, end_str, "Pittsburgh")
response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)
df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 query = """
#       2             SELECT "facility_name" as facility , COUNT("description_new") as count
#       3             FROM "{}"
#       4             WHERE "inspect_dt" BETWEEN '{}' AND '{}' AND "city" = '{}' AND "rating" = '{}' AND "facility_name" LIKE '%Pitt%'
#       5             GROUP BY "facility_name"
#       6             ORDER BY "count" DESC
#       7             LIMIT 20
#       8             """.format(resource_id, start_str, end_str, "Pittsburgh")
#       9 response = requests.get(wprdc_api_endpoint, {'sql': query}, verify=False)
#      10 df = pd.DataFrame.from_dict(json.loads(response.text)['result']['records'])
#
# IndexError: Replacement index 4 out of range for positional args tuple
